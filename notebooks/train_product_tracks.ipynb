# %% [markdown]
# # Product Track — 3 задачи, 6 моделей
#
# Для каждой задачи обучаются быстрый YOLO11n и точный YOLO11s. Каждой модели соответствует отдельная ячейка запуска обучения. Перед запуском подготовьте датасеты в формате YOLO и включите GPU.

# %%
# %pip install -q "ultralytics>=8.3,<9"

# %% [markdown]
# ## 1. Повреждения ЛЭП — YOLO11n

# %%
# !python scripts/train.py --task powerline --profile fast --data configs/powerline.yaml

# %% [markdown]
# ## 2. Повреждения ЛЭП — YOLO11s

# %%
# !python scripts/train.py --task powerline --profile accurate --data configs/powerline.yaml

# %% [markdown]
# ## 3. Переломы — YOLO11n

# %%
# !python scripts/train.py --task fracture --profile fast --data configs/fracture.yaml

# %% [markdown]
# ## 4. Переломы — YOLO11s

# %%
# !python scripts/train.py --task fracture --profile accurate --data configs/fracture.yaml

# %% [markdown]
# ## 5. Автотранспорт — YOLO11n

# %%
# !python scripts/train.py --task vehicle --profile fast --data configs/vehicle.yaml

# %% [markdown]
# ## 6. Автотранспорт — YOLO11s

# %%
# !python scripts/train.py --task vehicle --profile accurate --data configs/vehicle.yaml

# %% [markdown]
# ## Сравнение
#
# Для каждой пары моделей сравните mAP@0.5, mAP@0.5:0.95, precision, recall и latency на одном validation split. Не переносите метрики между задачами. Графики ЛЭП в проекте относятся только к предоставленному запуску ЛЭП.
